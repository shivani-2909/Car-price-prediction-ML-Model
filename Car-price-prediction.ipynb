# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import seaborn as sns 
sns.set()

# %% [markdown]
# ## Loading the dataset

# %%
raw_data = pd.read_csv(r'Downloads\CAR DETAILS FROM CAR DEKHO.csv')

# %% [markdown]
# ## Read about dataset

# %%
raw_data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
raw_data.describe(include = 'all')
# Out:
#                           name         year  selling_price      km_driven  \
# count                     4340  4340.000000   4.340000e+03    4340.000000
# unique                    1491          NaN            NaN            NaN
# top     Maruti Swift Dzire VDI          NaN            NaN            NaN
# freq                        69          NaN            NaN            NaN
# mean                       NaN  2013.090783   5.041273e+05   66215.777419
# std                        NaN     4.215344   5.785487e+05   46644.102194
# min                        NaN  1992.000000   2.000000e+04       1.000000
# 25%                        NaN  2011.000000   2.087498e+05   35000.000000
# 50%                        NaN  2014.000000   3.500000e+05   60000.000000
# 75%                        NaN  2016.000000   6.000000e+05   90000.000000
# max                        NaN  2020.000000   8.900000e+06  806599.000000
#
#           fuel seller_type transmission        owner
# count     4340        4340         4340         4340
# unique       5           3            2            5
# top     Diesel  Individual       Manual  First Owner
# freq      2153        3244         3892         2832
# mean       NaN         NaN          NaN          NaN
# std        NaN         NaN          NaN          NaN
# min        NaN         NaN          NaN          NaN
# 25%        NaN         NaN          NaN          NaN
# 50%        NaN         NaN          NaN          NaN
# 75%        NaN         NaN          NaN          NaN
# max        NaN         NaN          NaN          NaN

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# ## Drop the variable that is not necessary for our prediction

# %%
data = raw_data.drop(['name'], axis = 1)
data
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...            ...
# 4335  Second Owner
# 4336  Second Owner
# 4337  Second Owner
# 4338   First Owner
# 4339   First Owner
#
# [4340 rows x 7 columns]

# %% [markdown]
# ## Converting 'year' to 'age' column

# %%
max = data['year'].max()
age = data['year'].apply(lambda x:(max+1)-x)
data.drop(['year'], axis = 1, inplace = True)
data ['age'] = age
data
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner  \
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
#       age
# 0      14
# 1      14
# 2       9
# 3       4
# 4       7
# ...   ...
# 4335    7
# 4336    7
# 4337   12
# 4338    5
# 4339    5
#
# [4340 rows x 7 columns]

# %% [markdown]
# ## Exploring the PDF (Probability distributive function)

# %%
sns.displot(data['selling_price'])
plt.show()

# %%
sns.displot(data['km_driven'])
plt.show()

# %% [raw]
# Removing the outliers

# %%
q = data['km_driven'].quantile(0.99)
data = data[data['km_driven']<q]
data.describe(include = 'all')
# Out:
#         selling_price      km_driven    fuel seller_type transmission  \
# count    4.294000e+03    4294.000000    4294        4294         4294
# unique            NaN            NaN       5           3            2
# top               NaN            NaN  Petrol  Individual       Manual
# freq              NaN            NaN    2118        3204         3848
# mean     5.056701e+05   63857.645552     NaN         NaN          NaN
# std      5.810018e+05   39391.684738     NaN         NaN          NaN
# min      2.000000e+04       1.000000     NaN         NaN          NaN
# 25%      2.100000e+05   35000.000000     NaN         NaN          NaN
# 50%      3.535000e+05   60000.000000     NaN         NaN          NaN
# 75%      6.000000e+05   90000.000000     NaN         NaN          NaN
# max      8.900000e+06  218000.000000     NaN         NaN          NaN
#
#               owner          age
# count          4294  4294.000000
# unique            5          NaN
# top     First Owner          NaN
# freq           2810          NaN
# mean            NaN     7.871216
# std             NaN     4.207737
# min             NaN     1.000000
# 25%             NaN     4.000000
# 50%             NaN     7.000000
# 75%             NaN    10.000000
# max             NaN    29.000000

# %%
sns.displot(data['age'])
plt.show()

# %% [markdown]
# ## Checking the OLS assumption

# %%
f, (ax1,ax2,ax3) = plt.subplots(1, 3, sharey = True, figsize = (15,3))
ax1.scatter(data['age'],data['selling_price'])
ax1.set_title('Price and age')
ax2.scatter(data['km_driven'],data['selling_price'])
ax2.set_title('Price and km driven')

plt.show()

# %%
log_price = np.log(data['selling_price'])
data ['log_price'] = log_price
data
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner  \
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
#       age  log_price
# 0      14  11.002100
# 1      14  11.813030
# 2       9  13.304685
# 3       4  12.429216
# 4       7  13.017003
# ...   ...        ...
# 4335    7  12.923910
# 4336    7  12.923910
# 4337   12  11.608236
# 4338    5  13.670485
# 4339    5  12.323856
#
# [4294 rows x 8 columns]

# %%
f, (ax1,ax2,ax3) = plt.subplots(1, 3, sharey = True, figsize = (15,3))
ax1.scatter(data['age'],data['log_price'])
ax1.set_title('Price and age')
ax2.scatter(data['km_driven'],data['log_price'])
ax2.set_title('Price and km driven')

plt.show()

# %%
data.isnull().sum()
# Out:
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# age              0
# log_price        0
# dtype: int64

# %%
data.columns.values
# Out:
# array(['selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'age', 'log_price'], dtype=object)

# %% [markdown]
# ## Calculating VIF to check multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data[['km_driven','age']]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["Features"] = variables.columns

# %%
vif
# Out:
#         VIF   Features
# 0  3.935683  km_driven
# 1  3.935683        age

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data
# Out:
#       selling_price  km_driven  age  log_price  fuel_Diesel  fuel_Electric  \
# 0             60000      70000   14  11.002100            0              0
# 1            135000      50000   14  11.813030            0              0
# 2            600000     100000    9  13.304685            1              0
# 3            250000      46000    4  12.429216            0              0
# 4            450000     141000    7  13.017003            1              0
# ...             ...        ...  ...        ...          ...            ...
# 4335         409999      80000    7  12.923910            1              0
# 4336         409999      80000    7  12.923910            1              0
# 4337         110000      83000   12  11.608236            0              0
# 4338         865000      90000    5  13.670485            1              0
# 4339         225000      40000    5  12.323856            0              0
#
#       fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0            0            1                       1
# 1            0            1                       1
# 2            0            0                       1
# 3            0            1                       1
# 4            0            0                       1
# ...        ...          ...                     ...
# 4335         0            0                       1
# 4336         0            0                       1
# 4337         0            1                       1
# 4338         0            0                       1
# 4339         0            1                       1
#
#       seller_type_Trustmark Dealer  transmission_Manual  \
# 0                                0                    1
# 1                                0                    1
# 2                                0                    1
# 3                                0                    1
# 4                                0                    1
# ...                            ...                  ...
# 4335                             0                    1
# 4336                             0                    1
# 4337                             0                    1
# 4338                             0                    1
# 4339                             0                    1
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                              0                   0                     0
# 1                              0                   0                     0
# 2                              0                   0                     0
# 3                              0                   0                     0
# 4                              0                   1                     0
# ...                          ...                 ...                   ...
# 4335                           0                   1                     0
# 4336                           0                   1                     0
# 4337                           0                   1                     0
# 4338                           0                   0                     0
# 4339                           0                   0                     0
#
#       owner_Third Owner
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 4335                  0
# 4336                  0
# 4337                  0
# 4338                  0
# 4339                  0
#
# [4294 rows x 15 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data[[ 'fuel_Diesel', 'fuel_Electric', 'fuel_LPG', 'fuel_Petrol', 'seller_type_Individual', 'seller_type_Trustmark Dealer', 'transmission_Manual', 'owner_Fourth & Above Owner', 'owner_Second Owner', 'owner_Test Drive Car', 'owner_Third Owner']]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["Features"] = variables.columns

# %%
vif
# Out:
#          VIF                      Features
# 0   0.163928                   fuel_Diesel
# 1   1.001339                 fuel_Electric
# 2   1.066574                      fuel_LPG
# 3   0.189504                   fuel_Petrol
# 4   0.195691        seller_type_Individual
# 5   1.105230  seller_type_Trustmark Dealer
# 6   0.019622           transmission_Manual
# 7   1.039440    owner_Fourth & Above Owner
# 8   0.092394            owner_Second Owner
# 9   1.019259          owner_Test Drive Car
# 10  0.150954             owner_Third Owner

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Setting dependent and independent variables

# %%
target = data['log_price']
inputs = data.drop(['log_price'], axis = 1)

# %% [markdown]
# ## Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)
inputs_scaled
# Out:
# array([[-0.76716116,  0.15594839,  1.45672083, ..., -0.58434219,
#         -0.06304561, -0.27160346],
#        [-0.63805875, -0.35183211,  1.45672083, ..., -0.58434219,
#         -0.06304561, -0.27160346],
#        [ 0.16237618,  0.91761913,  0.26829524, ..., -0.58434219,
#         -0.06304561, -0.27160346],
#        ...,
#        [-0.68109289,  0.48600571,  0.98135059, ...,  1.71132603,
#         -0.06304561, -0.27160346],
#        [ 0.61853802,  0.66372889, -0.68244523, ..., -0.58434219,
#         -0.06304561, -0.27160346],
#        [-0.48313586, -0.60572236, -0.68244523, ..., -0.58434219,
#         -0.06304561, -0.27160346]])

# %%
## Split train-test data

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, target, test_size=0.2, random_state = 365)

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel('Targets (y_train)', size=18)
plt.ylabel('Predictions (y_hat)',size =18)
plt.xlim(8,20)
plt.ylim(8,20)
plt.show()

# %%
sns.displot(y_train - y_hat, kind='kde')
plt.title('Residual PDF', size = 18)
plt.show()

# %%
## Accuracy

# %%
reg.score(x_train, y_train)
# Out:
# 0.820108901932513

# %%
reg.intercept_
# Out:
# 12.76276097481908

# %%
reg.coef_
# Out:
# array([ 0.40148944,  0.00382722, -0.3683361 ,  0.17305713,  0.00879081,
#        -0.01137795,  0.01664563, -0.04766153,  0.03191892, -0.06143152,
#        -0.02185092, -0.00835694,  0.00175759, -0.01911657])

# %%
reg.summary = pd.DataFrame(inputs.columns.values, columns = ['Features'])
reg.summary ['Weights'] = reg.coef_
reg.summary
# Out:
#                         Features   Weights
# 0                  selling_price  0.401489
# 1                      km_driven  0.003827
# 2                            age -0.368336
# 3                    fuel_Diesel  0.173057
# 4                  fuel_Electric  0.008791
# 5                       fuel_LPG -0.011378
# 6                    fuel_Petrol  0.016646
# 7         seller_type_Individual -0.047662
# 8   seller_type_Trustmark Dealer  0.031919
# 9            transmission_Manual -0.061432
# 10    owner_Fourth & Above Owner -0.021851
# 11            owner_Second Owner -0.008357
# 12          owner_Test Drive Car  0.001758
# 13             owner_Third Owner -0.019117

# %% [markdown]
# ## Prediction

# %%
y_pred = reg.predict(x_test)

# %%
plt.scatter(y_test,y_pred, alpha = 0.2)
plt.xlabel('Targets (y_test)', size=18)
plt.ylabel('Predictions (y_hat_test)',size =18)
plt.xlim(8,20)
plt.ylim(8,20)
plt.show()

# %%
df_pf = pd.DataFrame(np.exp(y_pred), columns=['Prediction']) #performance
df_pf.head()
# Out:
#       Prediction
# 0  643205.426135
# 1  919749.350437
# 2  335711.670685
# 3  122028.636530
# 4  344714.888239

# %%
df_pf['Target'] = np.exp(y_test)
df_pf
# Out:
#         Prediction    Target
# 0    643205.426135       NaN
# 1    919749.350437  135000.0
# 2    335711.670685       NaN
# 3    122028.636530       NaN
# 4    344714.888239       NaN
# ..             ...       ...
# 854  338178.600425       NaN
# 855  314570.994125  400000.0
# 856  166964.651728       NaN
# 857  252671.713466       NaN
# 858  491925.148539       NaN
#
# [859 rows x 2 columns]

# %%
y_test = y_test.reset_index(drop=True)

# %%
y_test.head()
# Out:
# 0    13.091902
# 1    13.623139
# 2    13.122363
# 3    11.002100
# 4    12.409013
# Name: log_price, dtype: float64

# %%
df_pf['Target'] = np.exp(y_test)
df_pf
# Out:
#         Prediction    Target
# 0    643205.426135  484999.0
# 1    919749.350437  825000.0
# 2    335711.670685  500000.0
# 3    122028.636530   60000.0
# 4    344714.888239  245000.0
# ..             ...       ...
# 854  338178.600425  300000.0
# 855  314570.994125  185000.0
# 856  166964.651728  220000.0
# 857  252671.713466  133000.0
# 858  491925.148539  350000.0
#
# [859 rows x 2 columns]

# %% [markdown]
# ## Difference between Target and predicted value

# %%
df_pf['Residual'] = df_pf['Target'] - df_pf['Prediction']

# %%
df_pf['Difference%'] = np.absolute(df_pf['Residual']/df_pf['Target']*100)
df_pf.describe()
# Out:
#          Prediction        Target      Residual  Difference%
# count  8.590000e+02  8.590000e+02  8.590000e+02   859.000000
# mean   5.088256e+05  5.070348e+05 -1.790835e+03    28.237895
# std    9.548353e+05  5.390862e+05  5.811553e+05    28.796632
# min    5.253806e+04  3.500000e+04 -1.256561e+07     0.051171
# 25%    2.249766e+05  2.200000e+05 -4.610190e+04    10.055193
# 50%    3.521567e+05  3.650000e+05  1.376806e+04    21.457664
# 75%    5.070960e+05  6.000000e+05  1.073693e+05    35.515695
# max    1.736561e+07  4.800000e+06  1.474677e+06   261.783589
